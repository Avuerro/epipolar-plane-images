# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
import pdb
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from epipolar_plane_image import EpipolarPlaneImage

# %%
epi = EpipolarPlaneImage.load_from_video(output_dir='epi_output_dir',
                            video='./assets/Paul_Daley_2.mp4',
                             time_start=4,
                             time_end=20,
                             volume_height=450,
                             filename='epi_example')
# Out:
# front shape (270, 1280, 3) and top shape (800, 1280, 3) and side shape (270, 800, 3)

# %%
epi.construct_volume()

# %%
heights = [0,390,420,450]
for height in heights:
    EPI = EpipolarPlaneImage('./assets/Paul_Daley_2.mp4', 4, 20, height, f'epi_height_{height}')
    EPI.construct_volume()
